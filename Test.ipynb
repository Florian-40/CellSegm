# %%
import SimpleITK as sitk 
import numpy as np 
import matplotlib.pyplot as plt 
import os
from COp_Net.scripts.IterativeInf import Inference
from COp_Net.scripts.AllMetrics import Results

# %matplotlib notebook
# Out:
# /scratch/imb/frobert002/anaconda3/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/scratch/imb/frobert002/anaconda3/lib/python3.9/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# ...

# %%
import torch 
print("Torch device:", torch.cuda.is_available(), torch.cuda.device_count(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only")
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"
# Out:
# Torch device: True 1 NVIDIA RTX A6000

# %%
Inference('Images/probamap.nii.gz', 'Outputs', max_iter=5, device=device)
# Out:
# Iteration :  1
# /localdisk/frobert002/nnUNetv2/nnunetv2/utilities/plans_handling/plans_handler.py:37: UserWarning: Detected old nnU-Net plans format. Attempting to reconstruct network architecture parameters. If this fails, rerun nnUNetv2_plan_experiment for your dataset. If you use a custom architecture, please downgrade nnU-Net to the version you implemented this or update your implementation + plans.
#   warnings.warn("Detected old nnU-Net plans format. Attempting to reconstruct network architecture "
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# There are 1 cases in the source folder
# ...

# %%
# Read images to evaluate the performances
pred = sitk.ReadImage('Outputs/CopNet_5_0000.nii.gz')  #shape (1,512,512)
labels = sitk.ReadImage('Images/ground_truth.nii.gz')
proba_map = sitk.ReadImage('Images/probamap.nii.gz')
hemo = sitk.ReadImage('Images/hemo.nii.gz')
vessel = sitk.ReadImage('Images/vessel.nii.gz')

# Convert them to numpy array
pred = sitk.GetArrayFromImage(pred)[0,:,:]
labels = sitk.GetArrayFromImage(labels)
proba_map = sitk.GetArrayFromImage(proba_map)
hemo = sitk.GetArrayFromImage(hemo)
vessel = sitk.GetArrayFromImage(vessel)

                        
    
# Evaluate the performance of the current 2D or 3D image 
res = Results(pred, labels, proba_map, 'Images/background_orig.nii.gz', hemo, vessel)
res.LabellingMetrics(error_percentage = 0.15, slice_visualization = 0)
res.SegmentationMetrics()
# Out:
# <img src="data:image/png;base64,..." width="800">
# ...
# <img src="data:image/png;base64,..." width="900">
# Total number of cells:  90
# ---------------  Validation on 1 image --------------
#
# nnUNet + COp-Net:
# Proportion of correctly labelled cells : 0.644
# -------------------------------------------------------------------
# Proportion of erroneously merged component: 0.211
# Proportion of erroneously split component : 0.144
# -------------------------------------------------------------------
#
# nnUNet only:
# Proportion of correctly labelled cells : 0.3
# -------------------------------------------------------------------
# Proportion of erroneously merged component : 0.611
# Proportion of erroneously split component : 0.089
#
# -------------------------------------------------------------------
#
# Normalized Surface Dice (NSD):
#
# nnUNet + COp-Net:  0.9547144770622253
# nnUNet only:  0.8607801198959351
#
# Centerline Dice (clDice):
#
# nnUNet + COp-Net:  0.9162226335460584
# ...

# %% [markdown]
# # Visualisation of data in Images folder

# %%
background = sitk.ReadImage('Images/background.nii.gz')
background_orig = sitk.ReadImage('Images/background_orig.nii.gz')
proba_map = sitk.ReadImage('Images/probamap.nii.gz')
ground_truth = sitk.ReadImage('Images/ground_truth.nii.gz')
hemo = sitk.ReadImage('Images/hemo.nii.gz')
vessel = sitk.ReadImage('Images/vessel.nii.gz')

background = sitk.GetArrayFromImage(background)
background_orig = sitk.GetArrayFromImage(background_orig)
proba_map = sitk.GetArrayFromImage(proba_map)
ground_truth = sitk.GetArrayFromImage(ground_truth)
hemo = sitk.GetArrayFromImage(hemo)
vessel = sitk.GetArrayFromImage(vessel)

# %%
plt.figure(figsize=(9,7))

plt.subplot(231)
plt.imshow(background_orig, cmap='gray')
plt.title('SEM image from Stack #4 T2')
plt.axis('off')


plt.subplot(232)
plt.imshow(background, cmap='gray')
plt.title('SEM image with symetry \n on black borders')
plt.axis('off')


plt.subplot(234)
plt.imshow(proba_map)
plt.title('Input probability map')
plt.axis('off')


plt.subplot(235)
plt.imshow(ground_truth, cmap='gray')
plt.title('Cell contour ground truth')
plt.axis('off')


plt.subplot(233)
plt.imshow(vessel, cmap='gray')
plt.title('Blood capillary mask')
plt.axis('off')


plt.subplot(236)
plt.imshow(hemo, cmap='gray')
plt.title('Hemorragic area mask')
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
